# %%
import pandas as pd

# %%
df = pd.read_csv("results.csv")
df
# Out:
#               actor                   movie_or_TV_name
# 0      Chase Stokes                             Uglies
# 1      Chase Stokes                        Outer Banks
# 2      Chase Stokes  Paltrocast with Darren Paltrowitz
# 3      Chase Stokes               Tell Me Your Secrets
# 4      Chase Stokes    Dr. Bird's Advice for Sad Poets
# ...             ...                                ...
# 5652  Charles Esten           Whose Line Is It Anyway?
# 5653  Charles Esten                           Scrabble
# 5654  Charles Esten  Roots of the Cuban Missile Crisis
# 5655  Charles Esten           Whose Line Is It Anyway?
# 5656  Charles Esten           Whose Line Is It Anyway?
#
# [5657 rows x 2 columns]

# %%
df = df.groupby("movie_or_TV_name").count().sort_values(['actor'], ascending = False)

# %%
df = df.rename(columns = {'actor': 'Number of Shared Actors'})

# %%
df.head(100)
# Out:
#                                    Number of Shared Actors
# movie_or_TV_name
# Outer Banks                                            172
# The Walking Dead                                        21
# Mr. Mercedes                                            20
# MacGyver                                                18
# The Righteous Gemstones                                 18
# NCIS: New Orleans                                       18
# One Tree Hill                                           15
# The Inspectors                                          14
# Sleepy Hollow                                           14
# The Resident                                            13
# Army Wives                                              13
# Nashville                                               12
# Last Call                                               12
# Drop Dead Diva                                          12
# Revolution                                              11
# ...
